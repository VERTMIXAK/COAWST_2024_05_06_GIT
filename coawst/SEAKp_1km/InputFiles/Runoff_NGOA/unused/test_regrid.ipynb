# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#import ESMF
import numpy as np
import pandas as pd
import xarray as xr
import pyroms

# %%
grd = pyroms.grid.get_ROMS_grid('SEAKp_1km')
# Out:
# Assuming spherical is integer 1 <class 'numpy.ma.core.MaskedArray'>
# Load geographical grid from file

# %%
grd

# %%
lon2 = xr.DataArray(grd.hgrid.lon_psi)

# %%
ds_out = xr.Dataset({'lon': xr.DataArray(grd.hgrid.lon_psi), 'lat':xr.DataArray(grd.hgrid.lat_psi)})

# %%
ds_out
# Out:
# <xarray.Dataset>
# Dimensions:  (dim_0: 281, dim_1: 325)
# Dimensions without coordinates: dim_0, dim_1
# Data variables:
#     lon      (dim_0, dim_1) float64 212.0 212.1 212.1 ... 215.1 215.2 215.2
#     lat      (dim_0, dim_1) float64 48.03 48.06 48.08 48.11 ... 65.17 65.2 65.22

# %%
river_data = xr.open_dataset('/import/AKWATERS/kshedstrom/hydroflow//new_2019/goa_dischargex_09012014_08312015.nc')

# %%
river_data
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 365, timeSeries: 14052)
# Dimensions without coordinates: time, timeSeries
# Data variables:
#     q        (time, timeSeries) float32 ...
#     lon      (timeSeries) float32 ...
#     lat      (timeSeries) float32 ...
#     year     (time) uint32 ...
#     month    (time) uint32 ...
#     day      (time) uint32 ...
# Attributes:
#     title:          Coastal Freshwater Discharge into the Gulf of Alaska
#     summary:        Coastal FWD was modeled using a suite of physically based...
#     keywords:       DISCHARGE/FLOW, ALASKA, GULF OF ALASKA
#     date created:   Dataset created June 2019
#     creator_name:   David Hill, Professor
#     creator_email:  dfh@oregonstate.edu
#     institution:    Oregon State University, Department of Civil Engineering

# %%
len(river_data.year)
# Out:
# 365

# %%
river_data.lon[0:10]+360, river_data.lat[0:10]
# Out:
# (<xarray.DataArray 'lon' (timeSeries: 10)>
#  array([205.27757, 205.26134, 205.29362, 205.26097, 205.3097 , 205.24455,
#         205.32576, 205.22832, 205.24437, 205.34167], dtype=float32)
#  Dimensions without coordinates: timeSeries,
#  <xarray.DataArray 'lat' (timeSeries: 10)>
#  array([56.418037, 56.41794 , 56.4271  , 56.43587 , 56.436157, 56.444733,
#         56.445217, 56.44463 , 56.453697, 56.463234], dtype=float32)
#  Dimensions without coordinates: timeSeries
#  Attributes:
#      long_name:  latitude
#      units:      degrees_north)

# %%
len(river_data.timeSeries)
# Out:
# 14052

# %%
lon2d = grd.hgrid.lon_psi
lat2d = grd.hgrid.lat_psi
Mm, Ll = lat2d.shape

# %%
ii, jj = np.meshgrid(range(Ll), range(Mm))
grd2 = list( zip(np.ravel(lon2d), np.ravel(lat2d)) )
idx = list( zip(np.ravel(ii), np.ravel(jj)) )

# %%
pts = list( zip(np.ravel(river_data.lon + 360.), np.ravel(river_data.lat)) )

# %%
from scipy import spatial
distance, index = spatial.KDTree(grd2).query(pts)

# %%
pts_coord = np.asarray(grd2)[index]
pts_idx = np.asarray(idx)[index]
pts_coord
# Out:
# array([[205.26645132,  56.41341473],
#        [205.26645132,  56.41341473],
#        [205.31316416,  56.44461114],
#        ...,
#        [210.62113403,  61.55675419],
#        [210.68197962,  61.52861032],
#        [210.68197962,  61.52861032]])

# %%
pts_idx
# Out:
# array([[ 84, 216],
#        [ 84, 216],
#        [ 85, 216],
#        ...,
#        [224, 250],
#        [224, 249],
#        [224, 249]])

# %%
indices = xr.Dataset({'i': (['river'], pts_idx[:,0]), 'j': (['river'], pts_idx[:,1])})

# %%
indices
# Out:
# <xarray.Dataset>
# Dimensions:  (river: 14052)
# Dimensions without coordinates: river
# Data variables:
#     i        (river) int64 84 84 85 84 85 85 85 ... 223 223 224 224 224 224 224
#     j        (river) int64 216 216 216 216 216 217 ... 249 250 249 250 249 249

# %%
#indices.to_netcdf('indices.nc')

# %%
import pyroms_toolbox
width = 1
idx = []
idy = []
maskl = grd.hgrid.mask_rho.copy()
for w in range(width):
    lit = pyroms_toolbox.get_littoral2(maskl)
    idx.extend(lit[0])
    idy.extend(lit[1])
    maskl[lit] = 0

# %%
littoral_idx = (np.array(idx), np.array(idy))
maskl = np.zeros(grd.hgrid.mask_rho.shape)
maskl[littoral_idx] = 1

# %%
mask_idx = np.where(grd.hgrid.mask_rho == 0)

# %% [markdown]
# Make the runoff file

# %%
import netCDF4 as netCDF
from datetime import datetime
nt = len(river_data.time)
Mp, Lp = grd.hgrid.mask_rho.shape
#spval = -1e30
spval = -9999.
runoff_raw = np.zeros((Mp,Lp))
runoff = np.zeros((Mp,Lp))

# create runoff file
runoff_file = 'runoff_NGOA_Hill_2015.nc'
nc = netCDF.Dataset(runoff_file, 'w', format='NETCDF3_64BIT')
nc.Description = 'Hill & Beamer monthly climatology river discharge'
nc.Author = 'make_runoff_clim.py'
nc.Created = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
nc.title = 'Hill & Beamer river discharge'

# create dimensions and variables
nc.createDimension('xi_rho', np.size(grd.hgrid.mask_rho,1))
nc.createDimension('eta_rho', np.size(grd.hgrid.mask_rho,0))
nc.createDimension('runoff_time', None)

nc.createVariable('lon_rho', 'f8', ('eta_rho', 'xi_rho'))
nc.variables['lon_rho'].long_name = 'longitude of RHO-points'
nc.variables['lon_rho'].units = 'degree_east'
nc.variables['lon_rho'].field = 'lon_rho, scalar'
nc.variables['lon_rho'][:] = grd.hgrid.lon_rho

nc.createVariable('lat_rho', 'f8', ('eta_rho', 'xi_rho'))
nc.variables['lat_rho'].long_name = 'latitude of RHO-points'
nc.variables['lat_rho'].units = 'degree_north'
nc.variables['lat_rho'].field = 'lat_rho, scalar'
nc.variables['lat_rho'][:] = grd.hgrid.lat_rho

nc.createVariable('runoff_time', 'f8', ('runoff_time'))
nc.variables['runoff_time'].long_name = 'time'
nc.variables['runoff_time'].units = 'days since 1900-01-01 00:00:00'
#nc.variables['runoff_time'].cycle_length = 365.25

nc.createVariable('Runoff_raw', 'f8', ('runoff_time', 'eta_rho', 'xi_rho'), fill_value=spval)
nc.variables['Runoff_raw'].long_name = 'Dai_Trenberth River Runoff raw'
nc.variables['Runoff_raw'].units = 'kg/s/m^2'

nc.createVariable('Runoff', 'f8', ('runoff_time', 'eta_rho', 'xi_rho'), fill_value=spval)
nc.variables['Runoff'].long_name = 'Dai_Trenberth River Runoff'
nc.variables['Runoff'].units = 'kg/s/m^2'

# %%
import datetime
date1 = datetime.date(1900, 1, 1)

# %%
river_data.q.shape
# Out:
# (365, 14052)

# %%
nt
# Out:
# 365

# %%
river_data.q
# Out:
# <xarray.DataArray 'q' (time: 365, timeSeries: 14052)>
# [5128980 values with dtype=float32]
# Dimensions without coordinates: time, timeSeries
# Attributes:
#     long_name:       Daily discharge
#     units:           cubic meters per day
#     coordinates:     time lat lon
#     standard_name:   runoff_flux
#     standard_units:  kg m-2 s-1

# %%
for t in range(nt):
    flow = np.sum(river_data.q[t,:])
    dater = datetime.date(river_data.year[t], river_data.month[t], river_data.day[t])
    time = (dater - date1).days
    print('Remapping runoff for time %f' %time)
    runoff_raw = np.zeros((Mp,Lp))
    runoff = np.zeros((Mp,Lp))
    for ri in range(len(river_data.timeSeries)):
        i = indices.i[ri]
        j = indices.j[ri]
        if (i > 323 or j == 0):
   #         print("overflow", i, j, ri)
            continue
        runoff_raw[j,i] += float(river_data.q[t,ri])
        
    nflow = np.sum(runoff_raw)
    print('time', t, flow/nflow)
    idx = np.where(runoff_raw != 0)
    runoff = pyroms_toolbox.move_runoff(runoff_raw, \
                  np.array(idx).T + 1, np.array(littoral_idx).T + 1, maskl, \
                  grd.hgrid.x_rho, grd.hgrid.y_rho, grd.hgrid.dx, grd.hgrid.dy)

# write data in destination file
    nc.variables['Runoff'][t] = runoff
    nc.variables['Runoff_raw'][t] = runoff_raw
    nc.variables['runoff_time'][t] = time

    if t==5:
        print('Sum 3', np.sum(runoff_raw))
        print('Sum 4', np.sum(runoff))

nc.close()
# Out:
# Remapping runoff for time 41881.000000
# time 0 <xarray.DataArray 'q' ()>
# array(1.09366047)
# Remapping runoff for time 41882.000000
# time 1 <xarray.DataArray 'q' ()>
# array(1.10249175)
# Remapping runoff for time 41883.000000
# time 2 <xarray.DataArray 'q' ()>
# array(1.10282355)
# Remapping runoff for time 41884.000000
# time 3 <xarray.DataArray 'q' ()>
# array(1.09769306)
# Remapping runoff for time 41885.000000
# time 4 <xarray.DataArray 'q' ()>
# array(1.08290235)
# Remapping runoff for time 41886.000000
# time 5 <xarray.DataArray 'q' ()>
# array(1.06923241)
# Sum 3 3961187567.407959
# Sum 4 3961078529.1998944
# Remapping runoff for time 41887.000000
# time 6 <xarray.DataArray 'q' ()>
# array(1.06222854)
# Remapping runoff for time 41888.000000
# time 7 <xarray.DataArray 'q' ()>
# array(1.05991245)
# Remapping runoff for time 41889.000000
# time 8 <xarray.DataArray 'q' ()>
# array(1.05873317)
# Remapping runoff for time 41890.000000
# time 9 <xarray.DataArray 'q' ()>
# array(1.05626737)
# Remapping runoff for time 41891.000000
# time 10 <xarray.DataArray 'q' ()>
# array(1.0536552)
# Remapping runoff for time 41892.000000
# time 11 <xarray.DataArray 'q' ()>
# array(1.04994442)
# Remapping runoff for time 41893.000000
# time 12 <xarray.DataArray 'q' ()>
# array(1.04326929)
# Remapping runoff for time 41894.000000
# time 13 <xarray.DataArray 'q' ()>
# array(1.03794591)
# Remapping runoff for time 41895.000000
# time 14 <xarray.DataArray 'q' ()>
# array(1.03419562)
# Remapping runoff for time 41896.000000
# time 15 <xarray.DataArray 'q' ()>
# array(1.03323359)
# Remapping runoff for time 41897.000000
# time 16 <xarray.DataArray 'q' ()>
# array(1.03284998)
# Remapping runoff for time 41898.000000
# time 17 <xarray.DataArray 'q' ()>
# array(1.03424881)
# Remapping runoff for time 41899.000000
# time 18 <xarray.DataArray 'q' ()>
# array(1.03472169)
# Remapping runoff for time 41900.000000
# time 19 <xarray.DataArray 'q' ()>
# array(1.04671352)
# Remapping runoff for time 41901.000000
# time 20 <xarray.DataArray 'q' ()>
# array(1.07384016)
# Remapping runoff for time 41902.000000
# time 21 <xarray.DataArray 'q' ()>
# array(1.08655162)
# Remapping runoff for time 41903.000000
# time 22 <xarray.DataArray 'q' ()>
# array(1.09731138)
# Remapping runoff for time 41904.000000
# time 23 <xarray.DataArray 'q' ()>
# array(1.10580183)
# Remapping runoff for time 41905.000000
# time 24 <xarray.DataArray 'q' ()>
# array(1.11535809)
# Remapping runoff for time 41906.000000
# time 25 <xarray.DataArray 'q' ()>
# array(1.12085496)
# Remapping runoff for time 41907.000000
# time 26 <xarray.DataArray 'q' ()>
# array(1.11538458)
# Remapping runoff for time 41908.000000
# time 27 <xarray.DataArray 'q' ()>
# array(1.13250418)
# Remapping runoff for time 41909.000000
# time 28 <xarray.DataArray 'q' ()>
# array(1.17984091)
# Remapping runoff for time 41910.000000
# time 29 <xarray.DataArray 'q' ()>
# array(1.19537426)
# Remapping runoff for time 41911.000000
# time 30 <xarray.DataArray 'q' ()>
# array(1.20023706)
# Remapping runoff for time 41912.000000
# time 31 <xarray.DataArray 'q' ()>
# array(1.20292336)
# Remapping runoff for time 41913.000000
# time 32 <xarray.DataArray 'q' ()>
# array(1.20229568)
# Remapping runoff for time 41914.000000
# time 33 <xarray.DataArray 'q' ()>
# array(1.20248258)
# Remapping runoff for time 41915.000000
# time 34 <xarray.DataArray 'q' ()>
# array(1.18155502)
# Remapping runoff for time 41916.000000
# time 35 <xarray.DataArray 'q' ()>
# array(1.17447949)
# Remapping runoff for time 41917.000000
# time 36 <xarray.DataArray 'q' ()>
# array(1.16917044)
# Remapping runoff for time 41918.000000
# time 37 <xarray.DataArray 'q' ()>
# array(1.16455965)
# Remapping runoff for time 41919.000000
# time 38 <xarray.DataArray 'q' ()>
# array(1.15763789)
# Remapping runoff for time 41920.000000
# time 39 <xarray.DataArray 'q' ()>
# array(1.14125824)
# Remapping runoff for time 41921.000000
# time 40 <xarray.DataArray 'q' ()>
# array(1.13535044)
# Remapping runoff for time 41922.000000
# time 41 <xarray.DataArray 'q' ()>
# array(1.14750059)
# Remapping runoff for time 41923.000000
# time 42 <xarray.DataArray 'q' ()>
# array(1.16640188)
# Remapping runoff for time 41924.000000
# time 43 <xarray.DataArray 'q' ()>
# array(1.18070215)
# Remapping runoff for time 41925.000000
# time 44 <xarray.DataArray 'q' ()>
# array(1.19946325)
# Remapping runoff for time 41926.000000
# time 45 <xarray.DataArray 'q' ()>
# array(1.2202971)
# Remapping runoff for time 41927.000000
# time 46 <xarray.DataArray 'q' ()>
# array(1.25114375)
# Remapping runoff for time 41928.000000
# time 47 <xarray.DataArray 'q' ()>
# array(1.30497046)
# Remapping runoff for time 41929.000000
# time 48 <xarray.DataArray 'q' ()>
# array(1.32085641)
# Remapping runoff for time 41930.000000
# time 49 <xarray.DataArray 'q' ()>
# array(1.31132596)
# Remapping runoff for time 41931.000000
# time 50 <xarray.DataArray 'q' ()>
# array(1.30273501)
# Remapping runoff for time 41932.000000
# time 51 <xarray.DataArray 'q' ()>
# array(1.31060402)
# Remapping runoff for time 41933.000000
# time 52 <xarray.DataArray 'q' ()>
# array(1.30569234)
# Remapping runoff for time 41934.000000
# time 53 <xarray.DataArray 'q' ()>
# array(1.31248483)
# Remapping runoff for time 41935.000000
# time 54 <xarray.DataArray 'q' ()>
# array(1.31777179)
# Remapping runoff for time 41936.000000
# time 55 <xarray.DataArray 'q' ()>
# array(1.31162894)
# Remapping runoff for time 41937.000000
# time 56 <xarray.DataArray 'q' ()>
# array(1.30422468)
# Remapping runoff for time 41938.000000
# time 57 <xarray.DataArray 'q' ()>
# array(1.32479594)
# Remapping runoff for time 41939.000000
# time 58 <xarray.DataArray 'q' ()>
# array(1.35179026)
# Remapping runoff for time 41940.000000
# time 59 <xarray.DataArray 'q' ()>
# array(1.34951827)
# Remapping runoff for time 41941.000000
# time 60 <xarray.DataArray 'q' ()>
# array(1.3377384)
# Remapping runoff for time 41942.000000
# time 61 <xarray.DataArray 'q' ()>
# array(1.30241327)
# Remapping runoff for time 41943.000000
# time 62 <xarray.DataArray 'q' ()>
# array(1.27445749)
# Remapping runoff for time 41944.000000
# time 63 <xarray.DataArray 'q' ()>
# array(1.2416534)
# Remapping runoff for time 41945.000000
# time 64 <xarray.DataArray 'q' ()>
# array(1.22822058)
# Remapping runoff for time 41946.000000
# time 65 <xarray.DataArray 'q' ()>
# array(1.22795596)
# Remapping runoff for time 41947.000000
# time 66 <xarray.DataArray 'q' ()>
# array(1.23575207)
# Remapping runoff for time 41948.000000
# time 67 <xarray.DataArray 'q' ()>
# array(1.24212371)
# Remapping runoff for time 41949.000000
# time 68 <xarray.DataArray 'q' ()>
# array(1.22557409)
# Remapping runoff for time 41950.000000
# time 69 <xarray.DataArray 'q' ()>
# array(1.19081067)
# Remapping runoff for time 41951.000000
# time 70 <xarray.DataArray 'q' ()>
# array(1.15433697)
# Remapping runoff for time 41952.000000
# time 71 <xarray.DataArray 'q' ()>
# array(1.12137644)
# Remapping runoff for time 41953.000000
# time 72 <xarray.DataArray 'q' ()>
# array(1.08972881)
# Remapping runoff for time 41954.000000
# time 73 <xarray.DataArray 'q' ()>
# array(1.06697193)
# Remapping runoff for time 41955.000000
# time 74 <xarray.DataArray 'q' ()>
# array(1.05820693)
# Remapping runoff for time 41956.000000
# time 75 <xarray.DataArray 'q' ()>
# array(1.0550465)
# Remapping runoff for time 41957.000000
# time 76 <xarray.DataArray 'q' ()>
# array(1.05226308)
# Remapping runoff for time 41958.000000
# time 77 <xarray.DataArray 'q' ()>
# array(1.05036927)
# Remapping runoff for time 41959.000000
# time 78 <xarray.DataArray 'q' ()>
# array(1.05289)
# Remapping runoff for time 41960.000000
# time 79 <xarray.DataArray 'q' ()>
# array(1.06325417)
# Remapping runoff for time 41961.000000
# time 80 <xarray.DataArray 'q' ()>
# array(1.08946869)
# Remapping runoff for time 41962.000000
# time 81 <xarray.DataArray 'q' ()>
# array(1.12685013)
# Remapping runoff for time 41963.000000
# time 82 <xarray.DataArray 'q' ()>
# array(1.15401863)
# Remapping runoff for time 41964.000000
# time 83 <xarray.DataArray 'q' ()>
# array(1.16652902)
# Remapping runoff for time 41965.000000
# time 84 <xarray.DataArray 'q' ()>
# array(1.1821709)
# Remapping runoff for time 41966.000000
# time 85 <xarray.DataArray 'q' ()>
# array(1.2024889)
# Remapping runoff for time 41967.000000
# time 86 <xarray.DataArray 'q' ()>
# array(1.20645045)
# Remapping runoff for time 41968.000000
# time 87 <xarray.DataArray 'q' ()>
# array(1.19871106)
# Remapping runoff for time 41969.000000
# time 88 <xarray.DataArray 'q' ()>
# array(1.19101863)
# Remapping runoff for time 41970.000000
# time 89 <xarray.DataArray 'q' ()>
# array(1.178215)
# Remapping runoff for time 41971.000000
# time 90 <xarray.DataArray 'q' ()>
# array(1.16780907)
# Remapping runoff for time 41972.000000
# time 91 <xarray.DataArray 'q' ()>
# array(1.17238882)
# Remapping runoff for time 41973.000000
# time 92 <xarray.DataArray 'q' ()>
# array(1.15735222)
# Remapping runoff for time 41974.000000
# time 93 <xarray.DataArray 'q' ()>
# array(1.1326182)
# Remapping runoff for time 41975.000000
# time 94 <xarray.DataArray 'q' ()>
# array(1.11692977)
# Remapping runoff for time 41976.000000
# time 95 <xarray.DataArray 'q' ()>
# array(1.10064032)
# Remapping runoff for time 41977.000000
# time 96 <xarray.DataArray 'q' ()>
# array(1.10175838)
# Remapping runoff for time 41978.000000
# time 97 <xarray.DataArray 'q' ()>
# array(1.10860169)
# Remapping runoff for time 41979.000000
# time 98 <xarray.DataArray 'q' ()>
# array(1.10363754)
# Remapping runoff for time 41980.000000
# time 99 <xarray.DataArray 'q' ()>
# array(1.13665236)
# Remapping runoff for time 41981.000000
# time 100 <xarray.DataArray 'q' ()>
# array(1.17686993)
# Remapping runoff for time 41982.000000
# time 101 <xarray.DataArray 'q' ()>
# array(1.23755958)
# Remapping runoff for time 41983.000000
# time 102 <xarray.DataArray 'q' ()>
# array(1.31410131)
# Remapping runoff for time 41984.000000
# time 103 <xarray.DataArray 'q' ()>
# array(1.32223277)
# Remapping runoff for time 41985.000000
# time 104 <xarray.DataArray 'q' ()>
# array(1.27078715)
# Remapping runoff for time 41986.000000
# time 105 <xarray.DataArray 'q' ()>
# array(1.18460474)
# Remapping runoff for time 41987.000000
# time 106 <xarray.DataArray 'q' ()>
# array(1.1348238)
# Remapping runoff for time 41988.000000
# time 107 <xarray.DataArray 'q' ()>
# array(1.12138637)
# Remapping runoff for time 41989.000000
# time 108 <xarray.DataArray 'q' ()>
# array(1.11985329)
# Remapping runoff for time 41990.000000
# time 109 <xarray.DataArray 'q' ()>
# array(1.13702786)
# Remapping runoff for time 41991.000000
# time 110 <xarray.DataArray 'q' ()>
# array(1.17560459)
# Remapping runoff for time 41992.000000
# time 111 <xarray.DataArray 'q' ()>
# array(1.22458607)
# Remapping runoff for time 41993.000000
# time 112 <xarray.DataArray 'q' ()>
# array(1.24174899)
# Remapping runoff for time 41994.000000
# time 113 <xarray.DataArray 'q' ()>
# array(1.26144103)
# Remapping runoff for time 41995.000000
# time 114 <xarray.DataArray 'q' ()>
# array(1.33630712)
# Remapping runoff for time 41996.000000
# time 115 <xarray.DataArray 'q' ()>
# array(1.35034709)
# Remapping runoff for time 41997.000000
# time 116 <xarray.DataArray 'q' ()>
# array(1.30975887)
# Remapping runoff for time 41998.000000
# time 117 <xarray.DataArray 'q' ()>
# array(1.28640761)
# Remapping runoff for time 41999.000000
# time 118 <xarray.DataArray 'q' ()>
# array(1.2780027)
# Remapping runoff for time 42000.000000
# time 119 <xarray.DataArray 'q' ()>
# array(1.20441208)
# Remapping runoff for time 42001.000000
# time 120 <xarray.DataArray 'q' ()>
# array(1.11805806)
# Remapping runoff for time 42002.000000
# time 121 <xarray.DataArray 'q' ()>
# array(1.07867254)
# Remapping runoff for time 42003.000000
# time 122 <xarray.DataArray 'q' ()>
# array(1.08856841)
# Remapping runoff for time 42004.000000
# time 123 <xarray.DataArray 'q' ()>
# array(1.13900261)
# Remapping runoff for time 42005.000000
# time 124 <xarray.DataArray 'q' ()>
# array(1.17474745)
# Remapping runoff for time 42006.000000
# time 125 <xarray.DataArray 'q' ()>
# array(1.17553342)
# Remapping runoff for time 42007.000000
# time 126 <xarray.DataArray 'q' ()>
# array(1.1701469)
# Remapping runoff for time 42008.000000
# time 127 <xarray.DataArray 'q' ()>
# array(1.164047)
# Remapping runoff for time 42009.000000
# time 128 <xarray.DataArray 'q' ()>
# array(1.17778438)
# Remapping runoff for time 42010.000000
# time 129 <xarray.DataArray 'q' ()>
# array(1.18585528)
# Remapping runoff for time 42011.000000
# time 130 <xarray.DataArray 'q' ()>
# array(1.14409169)
# Remapping runoff for time 42012.000000
# time 131 <xarray.DataArray 'q' ()>
# array(1.1269802)
# Remapping runoff for time 42013.000000
# time 132 <xarray.DataArray 'q' ()>
# array(1.13277097)
# Remapping runoff for time 42014.000000
# time 133 <xarray.DataArray 'q' ()>
# array(1.13062647)
# Remapping runoff for time 42015.000000
# time 134 <xarray.DataArray 'q' ()>
# array(1.12831369)
# Remapping runoff for time 42016.000000
# time 135 <xarray.DataArray 'q' ()>
# array(1.12487647)
# Remapping runoff for time 42017.000000
# time 136 <xarray.DataArray 'q' ()>
# array(1.12315807)
# Remapping runoff for time 42018.000000
# time 137 <xarray.DataArray 'q' ()>
# array(1.12882573)
# Remapping runoff for time 42019.000000
# time 138 <xarray.DataArray 'q' ()>
# array(1.13233179)
# Remapping runoff for time 42020.000000
# time 139 <xarray.DataArray 'q' ()>
# array(1.16376326)
# Remapping runoff for time 42021.000000
# time 140 <xarray.DataArray 'q' ()>
# array(1.18648884)
# Remapping runoff for time 42022.000000
# time 141 <xarray.DataArray 'q' ()>
# array(1.20995642)
# Remapping runoff for time 42023.000000
# time 142 <xarray.DataArray 'q' ()>
# array(1.2880789)
# Remapping runoff for time 42024.000000
# time 143 <xarray.DataArray 'q' ()>
# array(1.34046694)
# Remapping runoff for time 42025.000000
# time 144 <xarray.DataArray 'q' ()>
# array(1.31127863)
# Remapping runoff for time 42026.000000
# time 145 <xarray.DataArray 'q' ()>
# array(1.28253039)
# Remapping runoff for time 42027.000000
# time 146 <xarray.DataArray 'q' ()>
# array(1.26995657)
# Remapping runoff for time 42028.000000
# time 147 <xarray.DataArray 'q' ()>
# array(1.25998059)
# Remapping runoff for time 42029.000000
# time 148 <xarray.DataArray 'q' ()>
# array(1.25853304)
# Remapping runoff for time 42030.000000
# time 149 <xarray.DataArray 'q' ()>
# array(1.26968049)
# Remapping runoff for time 42031.000000
# time 150 <xarray.DataArray 'q' ()>
# array(1.32174298)
# Remapping runoff for time 42032.000000
# time 151 <xarray.DataArray 'q' ()>
# array(1.3726534)
# Remapping runoff for time 42033.000000
# time 152 <xarray.DataArray 'q' ()>
# array(1.36094839)
# Remapping runoff for time 42034.000000
# time 153 <xarray.DataArray 'q' ()>
# array(1.32976275)
# Remapping runoff for time 42035.000000
# time 154 <xarray.DataArray 'q' ()>
# array(1.3083341)
# Remapping runoff for time 42036.000000
# time 155 <xarray.DataArray 'q' ()>
# array(1.28836653)
# Remapping runoff for time 42037.000000
# time 156 <xarray.DataArray 'q' ()>
# array(1.26162148)
# Remapping runoff for time 42038.000000
# time 157 <xarray.DataArray 'q' ()>
# array(1.24795184)
# Remapping runoff for time 42039.000000
# time 158 <xarray.DataArray 'q' ()>
# array(1.27042837)
# Remapping runoff for time 42040.000000
# time 159 <xarray.DataArray 'q' ()>
# array(1.31409345)
# Remapping runoff for time 42041.000000
# time 160 <xarray.DataArray 'q' ()>
# array(1.3090673)
# Remapping runoff for time 42042.000000
# time 161 <xarray.DataArray 'q' ()>
# array(1.30386553)
# Remapping runoff for time 42043.000000
# time 162 <xarray.DataArray 'q' ()>
# array(1.25978197)
# Remapping runoff for time 42044.000000
# time 163 <xarray.DataArray 'q' ()>
# array(1.27714691)
# Remapping runoff for time 42045.000000
# time 164 <xarray.DataArray 'q' ()>
# array(1.3752315)
# Remapping runoff for time 42046.000000
# time 165 <xarray.DataArray 'q' ()>
# array(1.40719996)
# Remapping runoff for time 42047.000000
# time 166 <xarray.DataArray 'q' ()>
# array(1.35174947)
# Remapping runoff for time 42048.000000
# time 167 <xarray.DataArray 'q' ()>
# array(1.29992215)
# Remapping runoff for time 42049.000000
# time 168 <xarray.DataArray 'q' ()>
# array(1.2465577)
# Remapping runoff for time 42050.000000
# time 169 <xarray.DataArray 'q' ()>
# array(1.1653098)
# Remapping runoff for time 42051.000000
# time 170 <xarray.DataArray 'q' ()>
# array(1.14107829)
# Remapping runoff for time 42052.000000
# time 171 <xarray.DataArray 'q' ()>
# array(1.14466676)
# Remapping runoff for time 42053.000000
# time 172 <xarray.DataArray 'q' ()>
# array(1.15302592)
# Remapping runoff for time 42054.000000
# time 173 <xarray.DataArray 'q' ()>
# array(1.13351521)
# Remapping runoff for time 42055.000000
# time 174 <xarray.DataArray 'q' ()>
# array(1.09303016)
# Remapping runoff for time 42056.000000
# time 175 <xarray.DataArray 'q' ()>
# array(1.06917406)
# Remapping runoff for time 42057.000000
# time 176 <xarray.DataArray 'q' ()>
# array(1.06343138)
# Remapping runoff for time 42058.000000
# time 177 <xarray.DataArray 'q' ()>
# array(1.07465232)
# Remapping runoff for time 42059.000000
# time 178 <xarray.DataArray 'q' ()>
# array(1.09378585)
# Remapping runoff for time 42060.000000
# time 179 <xarray.DataArray 'q' ()>
# array(1.11923252)
# Remapping runoff for time 42061.000000
# time 180 <xarray.DataArray 'q' ()>
# array(1.14154275)
# Remapping runoff for time 42062.000000
# time 181 <xarray.DataArray 'q' ()>
# array(1.16113499)
# Remapping runoff for time 42063.000000
# time 182 <xarray.DataArray 'q' ()>
# array(1.17454497)
# Remapping runoff for time 42064.000000
# time 183 <xarray.DataArray 'q' ()>
# array(1.16845435)
# Remapping runoff for time 42065.000000
# time 184 <xarray.DataArray 'q' ()>
# array(1.15633549)
# Remapping runoff for time 42066.000000
# time 185 <xarray.DataArray 'q' ()>
# array(1.19037588)
# Remapping runoff for time 42067.000000
# time 186 <xarray.DataArray 'q' ()>
# array(1.2456435)
# Remapping runoff for time 42068.000000
# time 187 <xarray.DataArray 'q' ()>
# array(1.23013695)
# Remapping runoff for time 42069.000000
# time 188 <xarray.DataArray 'q' ()>
# array(1.20421077)
# Remapping runoff for time 42070.000000
# time 189 <xarray.DataArray 'q' ()>
# array(1.20155296)
# Remapping runoff for time 42071.000000
# time 190 <xarray.DataArray 'q' ()>
# array(1.22310828)
# Remapping runoff for time 42072.000000
# time 191 <xarray.DataArray 'q' ()>
# array(1.27296382)
# Remapping runoff for time 42073.000000
# time 192 <xarray.DataArray 'q' ()>
# array(1.39375843)
# Remapping runoff for time 42074.000000
# time 193 <xarray.DataArray 'q' ()>
# array(1.57541757)
# Remapping runoff for time 42075.000000
# time 194 <xarray.DataArray 'q' ()>
# array(1.73503863)
# Remapping runoff for time 42076.000000
# time 195 <xarray.DataArray 'q' ()>
# array(1.76394351)
# Remapping runoff for time 42077.000000
# time 196 <xarray.DataArray 'q' ()>
# array(1.70435462)
# Remapping runoff for time 42078.000000
# time 197 <xarray.DataArray 'q' ()>
# array(1.58374523)
# Remapping runoff for time 42079.000000
# time 198 <xarray.DataArray 'q' ()>
# array(1.48685422)
# Remapping runoff for time 42080.000000
# time 199 <xarray.DataArray 'q' ()>
# array(1.39410414)
# Remapping runoff for time 42081.000000
# time 200 <xarray.DataArray 'q' ()>
# array(1.34639155)
# Remapping runoff for time 42082.000000
# time 201 <xarray.DataArray 'q' ()>
# array(1.32283764)
# Remapping runoff for time 42083.000000
# time 202 <xarray.DataArray 'q' ()>
# array(1.28454374)
# Remapping runoff for time 42084.000000
# time 203 <xarray.DataArray 'q' ()>
# array(1.27603781)
# Remapping runoff for time 42085.000000
# time 204 <xarray.DataArray 'q' ()>
# array(1.27759042)
# Remapping runoff for time 42086.000000
# time 205 <xarray.DataArray 'q' ()>
# array(1.27750363)
# Remapping runoff for time 42087.000000
# time 206 <xarray.DataArray 'q' ()>
# array(1.2629729)
# Remapping runoff for time 42088.000000
# time 207 <xarray.DataArray 'q' ()>
# array(1.25728027)
# Remapping runoff for time 42089.000000
# time 208 <xarray.DataArray 'q' ()>
# array(1.25464657)
# Remapping runoff for time 42090.000000
# time 209 <xarray.DataArray 'q' ()>
# array(1.26575535)
# Remapping runoff for time 42091.000000
# time 210 <xarray.DataArray 'q' ()>
# array(1.26104447)
# Remapping runoff for time 42092.000000
# time 211 <xarray.DataArray 'q' ()>
# array(1.26840669)
# Remapping runoff for time 42093.000000
# time 212 <xarray.DataArray 'q' ()>
# array(1.27530073)
# Remapping runoff for time 42094.000000
# time 213 <xarray.DataArray 'q' ()>
# array(1.27463316)
# Remapping runoff for time 42095.000000
# time 214 <xarray.DataArray 'q' ()>
# array(1.28078875)
# Remapping runoff for time 42096.000000
# time 215 <xarray.DataArray 'q' ()>
# array(1.28509315)
# Remapping runoff for time 42097.000000
# time 216 <xarray.DataArray 'q' ()>
# array(1.28383203)
# Remapping runoff for time 42098.000000
# time 217 <xarray.DataArray 'q' ()>
# array(1.26868384)
# Remapping runoff for time 42099.000000
# time 218 <xarray.DataArray 'q' ()>
# array(1.2208338)
# Remapping runoff for time 42100.000000
# time 219 <xarray.DataArray 'q' ()>
# array(1.16533668)
# Remapping runoff for time 42101.000000
# time 220 <xarray.DataArray 'q' ()>
# array(1.15905037)
# Remapping runoff for time 42102.000000
# time 221 <xarray.DataArray 'q' ()>
# array(1.17505311)
# Remapping runoff for time 42103.000000
# time 222 <xarray.DataArray 'q' ()>
# array(1.19345987)
# Remapping runoff for time 42104.000000
# time 223 <xarray.DataArray 'q' ()>
# array(1.2059478)
# Remapping runoff for time 42105.000000
# time 224 <xarray.DataArray 'q' ()>
# array(1.22016071)
# Remapping runoff for time 42106.000000
# time 225 <xarray.DataArray 'q' ()>
# array(1.24224023)
# Remapping runoff for time 42107.000000
# time 226 <xarray.DataArray 'q' ()>
# array(1.25121677)
# Remapping runoff for time 42108.000000
# time 227 <xarray.DataArray 'q' ()>
# array(1.23637968)
# Remapping runoff for time 42109.000000
# time 228 <xarray.DataArray 'q' ()>
# array(1.20476546)
# Remapping runoff for time 42110.000000
# time 229 <xarray.DataArray 'q' ()>
# array(1.17700594)
# Remapping runoff for time 42111.000000
# time 230 <xarray.DataArray 'q' ()>
# array(1.14027562)
# Remapping runoff for time 42112.000000
# time 231 <xarray.DataArray 'q' ()>
# array(1.13366228)
# Remapping runoff for time 42113.000000
# time 232 <xarray.DataArray 'q' ()>
# array(1.16368967)
# Remapping runoff for time 42114.000000
# time 233 <xarray.DataArray 'q' ()>
# array(1.18210902)
# Remapping runoff for time 42115.000000
# time 234 <xarray.DataArray 'q' ()>
# array(1.19461494)
# Remapping runoff for time 42116.000000
# time 235 <xarray.DataArray 'q' ()>
# array(1.20349551)
# Remapping runoff for time 42117.000000
# time 236 <xarray.DataArray 'q' ()>
# array(1.20609089)
# Remapping runoff for time 42118.000000
# time 237 <xarray.DataArray 'q' ()>
# array(1.21709889)
# Remapping runoff for time 42119.000000
# time 238 <xarray.DataArray 'q' ()>
# array(1.23599738)
# Remapping runoff for time 42120.000000
# time 239 <xarray.DataArray 'q' ()>
# array(1.26388426)
# Remapping runoff for time 42121.000000
# time 240 <xarray.DataArray 'q' ()>
# array(1.29792868)
# Remapping runoff for time 42122.000000
# time 241 <xarray.DataArray 'q' ()>
# array(1.30992147)
# Remapping runoff for time 42123.000000
# time 242 <xarray.DataArray 'q' ()>
# array(1.31380859)
# Remapping runoff for time 42124.000000
# time 243 <xarray.DataArray 'q' ()>
# array(1.30067367)
# Remapping runoff for time 42125.000000
# time 244 <xarray.DataArray 'q' ()>
# array(1.27804676)
# Remapping runoff for time 42126.000000
# time 245 <xarray.DataArray 'q' ()>
# array(1.25350521)
# Remapping runoff for time 42127.000000
# time 246 <xarray.DataArray 'q' ()>
# array(1.23300393)
# Remapping runoff for time 42128.000000
# time 247 <xarray.DataArray 'q' ()>
# array(1.21746505)
# Remapping runoff for time 42129.000000
# time 248 <xarray.DataArray 'q' ()>
# array(1.20109669)
# Remapping runoff for time 42130.000000
# time 249 <xarray.DataArray 'q' ()>
# array(1.1755069)
# Remapping runoff for time 42131.000000
# time 250 <xarray.DataArray 'q' ()>
# array(1.14912655)
# Remapping runoff for time 42132.000000
# time 251 <xarray.DataArray 'q' ()>
# array(1.14003805)
# Remapping runoff for time 42133.000000
# time 252 <xarray.DataArray 'q' ()>
# array(1.14376015)
# Remapping runoff for time 42134.000000
# time 253 <xarray.DataArray 'q' ()>
# array(1.14874963)
# Remapping runoff for time 42135.000000
# time 254 <xarray.DataArray 'q' ()>
# array(1.15397915)
# Remapping runoff for time 42136.000000
# time 255 <xarray.DataArray 'q' ()>
# array(1.15569846)
# Remapping runoff for time 42137.000000
# time 256 <xarray.DataArray 'q' ()>
# array(1.15184877)
# Remapping runoff for time 42138.000000
# time 257 <xarray.DataArray 'q' ()>
# array(1.14888371)
# Remapping runoff for time 42139.000000
# time 258 <xarray.DataArray 'q' ()>
# array(1.15172442)
# Remapping runoff for time 42140.000000
# time 259 <xarray.DataArray 'q' ()>
# array(1.15794776)
# Remapping runoff for time 42141.000000
# time 260 <xarray.DataArray 'q' ()>
# array(1.16020408)
# Remapping runoff for time 42142.000000
# time 261 <xarray.DataArray 'q' ()>
# array(1.16061186)
# Remapping runoff for time 42143.000000
# time 262 <xarray.DataArray 'q' ()>
# array(1.16044205)
# Remapping runoff for time 42144.000000
# time 263 <xarray.DataArray 'q' ()>
# array(1.16580312)
# Remapping runoff for time 42145.000000
# time 264 <xarray.DataArray 'q' ()>
# array(1.16992473)
# Remapping runoff for time 42146.000000
# time 265 <xarray.DataArray 'q' ()>
# array(1.17241384)
# Remapping runoff for time 42147.000000
# time 266 <xarray.DataArray 'q' ()>
# array(1.17458996)
# Remapping runoff for time 42148.000000
# time 267 <xarray.DataArray 'q' ()>
# array(1.17544877)
# Remapping runoff for time 42149.000000
# time 268 <xarray.DataArray 'q' ()>
# array(1.17545091)
# Remapping runoff for time 42150.000000
# time 269 <xarray.DataArray 'q' ()>
# array(1.17463688)
# Remapping runoff for time 42151.000000
# time 270 <xarray.DataArray 'q' ()>
# array(1.17155959)
# Remapping runoff for time 42152.000000
# time 271 <xarray.DataArray 'q' ()>
# array(1.16643678)
# Remapping runoff for time 42153.000000
# time 272 <xarray.DataArray 'q' ()>
# array(1.16012406)
# Remapping runoff for time 42154.000000
# time 273 <xarray.DataArray 'q' ()>
# array(1.15358882)
# Remapping runoff for time 42155.000000
# time 274 <xarray.DataArray 'q' ()>
# array(1.14731168)
# Remapping runoff for time 42156.000000
# time 275 <xarray.DataArray 'q' ()>
# array(1.14051519)
# Remapping runoff for time 42157.000000
# time 276 <xarray.DataArray 'q' ()>
# array(1.13178619)
# Remapping runoff for time 42158.000000
# time 277 <xarray.DataArray 'q' ()>
# array(1.12670036)
# Remapping runoff for time 42159.000000
# time 278 <xarray.DataArray 'q' ()>
# array(1.12562663)
# Remapping runoff for time 42160.000000
# time 279 <xarray.DataArray 'q' ()>
# array(1.1321481)
# Remapping runoff for time 42161.000000
# time 280 <xarray.DataArray 'q' ()>
# array(1.14023657)
# Remapping runoff for time 42162.000000
# time 281 <xarray.DataArray 'q' ()>
# array(1.14468653)
# Remapping runoff for time 42163.000000
# time 282 <xarray.DataArray 'q' ()>
# array(1.14387167)
# Remapping runoff for time 42164.000000
# time 283 <xarray.DataArray 'q' ()>
# array(1.14447928)
# Remapping runoff for time 42165.000000
# time 284 <xarray.DataArray 'q' ()>
# array(1.14740271)
# Remapping runoff for time 42166.000000
# time 285 <xarray.DataArray 'q' ()>
# array(1.14804118)
# Remapping runoff for time 42167.000000
# time 286 <xarray.DataArray 'q' ()>
# array(1.14501953)
# Remapping runoff for time 42168.000000
# time 287 <xarray.DataArray 'q' ()>
# array(1.13970378)
# Remapping runoff for time 42169.000000
# time 288 <xarray.DataArray 'q' ()>
# array(1.13340963)
# Remapping runoff for time 42170.000000
# time 289 <xarray.DataArray 'q' ()>
# array(1.12750452)
# Remapping runoff for time 42171.000000
# time 290 <xarray.DataArray 'q' ()>
# array(1.12188738)
# Remapping runoff for time 42172.000000
# time 291 <xarray.DataArray 'q' ()>
# array(1.11731432)
# Remapping runoff for time 42173.000000
# time 292 <xarray.DataArray 'q' ()>
# array(1.11315259)
# Remapping runoff for time 42174.000000
# time 293 <xarray.DataArray 'q' ()>
# array(1.10960411)
# Remapping runoff for time 42175.000000
# time 294 <xarray.DataArray 'q' ()>
# array(1.10651127)
# Remapping runoff for time 42176.000000
# time 295 <xarray.DataArray 'q' ()>
# array(1.10385803)
# Remapping runoff for time 42177.000000
# time 296 <xarray.DataArray 'q' ()>
# array(1.10162823)
# Remapping runoff for time 42178.000000
# time 297 <xarray.DataArray 'q' ()>
# array(1.10137692)
# Remapping runoff for time 42179.000000
# time 298 <xarray.DataArray 'q' ()>
# array(1.0966264)
# Remapping runoff for time 42180.000000
# time 299 <xarray.DataArray 'q' ()>
# array(1.09227844)
# Remapping runoff for time 42181.000000
# time 300 <xarray.DataArray 'q' ()>
# array(1.08858744)
# Remapping runoff for time 42182.000000
# time 301 <xarray.DataArray 'q' ()>
# array(1.08611969)
# Remapping runoff for time 42183.000000
# time 302 <xarray.DataArray 'q' ()>
# array(1.08467559)
# Remapping runoff for time 42184.000000
# time 303 <xarray.DataArray 'q' ()>
# array(1.08441011)
# Remapping runoff for time 42185.000000
# time 304 <xarray.DataArray 'q' ()>
# array(1.08300659)
# Remapping runoff for time 42186.000000
# time 305 <xarray.DataArray 'q' ()>
# array(1.08253768)
# Remapping runoff for time 42187.000000
# time 306 <xarray.DataArray 'q' ()>
# array(1.08245294)
# Remapping runoff for time 42188.000000
# time 307 <xarray.DataArray 'q' ()>
# array(1.0820475)
# Remapping runoff for time 42189.000000
# time 308 <xarray.DataArray 'q' ()>
# array(1.08086509)
# Remapping runoff for time 42190.000000
# time 309 <xarray.DataArray 'q' ()>
# array(1.07869919)
# Remapping runoff for time 42191.000000
# time 310 <xarray.DataArray 'q' ()>
# array(1.07697505)
# Remapping runoff for time 42192.000000
# time 311 <xarray.DataArray 'q' ()>
# array(1.07589554)
# Remapping runoff for time 42193.000000
# time 312 <xarray.DataArray 'q' ()>
# array(1.07517557)
# Remapping runoff for time 42194.000000
# time 313 <xarray.DataArray 'q' ()>
# array(1.07599879)
# Remapping runoff for time 42195.000000
# time 314 <xarray.DataArray 'q' ()>
# array(1.0749621)
# Remapping runoff for time 42196.000000
# time 315 <xarray.DataArray 'q' ()>
# array(1.07238684)
# Remapping runoff for time 42197.000000
# time 316 <xarray.DataArray 'q' ()>
# array(1.07174991)
# Remapping runoff for time 42198.000000
# time 317 <xarray.DataArray 'q' ()>
# array(1.07249615)
# Remapping runoff for time 42199.000000
# time 318 <xarray.DataArray 'q' ()>
# array(1.07228294)
# Remapping runoff for time 42200.000000
# time 319 <xarray.DataArray 'q' ()>
# array(1.06911863)
# Remapping runoff for time 42201.000000
# time 320 <xarray.DataArray 'q' ()>
# array(1.06712711)
# Remapping runoff for time 42202.000000
# time 321 <xarray.DataArray 'q' ()>
# array(1.06712044)
# Remapping runoff for time 42203.000000
# time 322 <xarray.DataArray 'q' ()>
# array(1.06947124)
# Remapping runoff for time 42204.000000
# time 323 <xarray.DataArray 'q' ()>
# array(1.07103659)
# Remapping runoff for time 42205.000000
# time 324 <xarray.DataArray 'q' ()>
# array(1.07194027)
# Remapping runoff for time 42206.000000
# time 325 <xarray.DataArray 'q' ()>
# array(1.0728079)
# Remapping runoff for time 42207.000000
# time 326 <xarray.DataArray 'q' ()>
# array(1.07589429)
# Remapping runoff for time 42208.000000
# time 327 <xarray.DataArray 'q' ()>
# array(1.0789931)
# Remapping runoff for time 42209.000000
# time 328 <xarray.DataArray 'q' ()>
# array(1.07792087)
# Remapping runoff for time 42210.000000
# time 329 <xarray.DataArray 'q' ()>
# array(1.07729352)
# Remapping runoff for time 42211.000000
# time 330 <xarray.DataArray 'q' ()>
# array(1.08027352)
# Remapping runoff for time 42212.000000
# time 331 <xarray.DataArray 'q' ()>
# array(1.0838685)
# Remapping runoff for time 42213.000000
# time 332 <xarray.DataArray 'q' ()>
# array(1.0881892)
# Remapping runoff for time 42214.000000
# time 333 <xarray.DataArray 'q' ()>
# array(1.09718818)
# Remapping runoff for time 42215.000000
# time 334 <xarray.DataArray 'q' ()>
# array(1.1090688)
# Remapping runoff for time 42216.000000
# time 335 <xarray.DataArray 'q' ()>
# array(1.10920433)
# Remapping runoff for time 42217.000000
# time 336 <xarray.DataArray 'q' ()>
# array(1.10506842)
# Remapping runoff for time 42218.000000
# time 337 <xarray.DataArray 'q' ()>
# array(1.09951727)
# Remapping runoff for time 42219.000000
# time 338 <xarray.DataArray 'q' ()>
# array(1.09431537)
# Remapping runoff for time 42220.000000
# time 339 <xarray.DataArray 'q' ()>
# array(1.08794622)
# Remapping runoff for time 42221.000000
# time 340 <xarray.DataArray 'q' ()>
# array(1.08371113)
# Remapping runoff for time 42222.000000
# time 341 <xarray.DataArray 'q' ()>
# array(1.07970092)
# Remapping runoff for time 42223.000000
# time 342 <xarray.DataArray 'q' ()>
# array(1.07494846)
# Remapping runoff for time 42224.000000
# time 343 <xarray.DataArray 'q' ()>
# array(1.06863336)
# Remapping runoff for time 42225.000000
# time 344 <xarray.DataArray 'q' ()>
# array(1.06578374)
# Remapping runoff for time 42226.000000
# time 345 <xarray.DataArray 'q' ()>
# array(1.06577798)
# Remapping runoff for time 42227.000000
# time 346 <xarray.DataArray 'q' ()>
# array(1.06903615)
# Remapping runoff for time 42228.000000
# time 347 <xarray.DataArray 'q' ()>
# array(1.0713065)
# Remapping runoff for time 42229.000000
# time 348 <xarray.DataArray 'q' ()>
# array(1.07218594)
# Remapping runoff for time 42230.000000
# time 349 <xarray.DataArray 'q' ()>
# array(1.07114802)
# Remapping runoff for time 42231.000000
# time 350 <xarray.DataArray 'q' ()>
# array(1.06637821)
# Remapping runoff for time 42232.000000
# time 351 <xarray.DataArray 'q' ()>
# array(1.05776096)
# Remapping runoff for time 42233.000000
# time 352 <xarray.DataArray 'q' ()>
# array(1.05391449)
# Remapping runoff for time 42234.000000
# time 353 <xarray.DataArray 'q' ()>
# array(1.05369866)
# Remapping runoff for time 42235.000000
# time 354 <xarray.DataArray 'q' ()>
# array(1.05513977)
# Remapping runoff for time 42236.000000
# time 355 <xarray.DataArray 'q' ()>
# array(1.05760943)
# Remapping runoff for time 42237.000000
# time 356 <xarray.DataArray 'q' ()>
# array(1.05977359)
# Remapping runoff for time 42238.000000
# time 357 <xarray.DataArray 'q' ()>
# array(1.06372416)
# Remapping runoff for time 42239.000000
# time 358 <xarray.DataArray 'q' ()>
# array(1.06859669)
# Remapping runoff for time 42240.000000
# time 359 <xarray.DataArray 'q' ()>
# array(1.0711495)
# Remapping runoff for time 42241.000000
# time 360 <xarray.DataArray 'q' ()>
# array(1.06971399)
# Remapping runoff for time 42242.000000
# time 361 <xarray.DataArray 'q' ()>
# array(1.07833663)
# Remapping runoff for time 42243.000000
# time 362 <xarray.DataArray 'q' ()>
# array(1.10463022)
# Remapping runoff for time 42244.000000
# time 363 <xarray.DataArray 'q' ()>
# array(1.12968823)
# Remapping runoff for time 42245.000000
# time 364 <xarray.DataArray 'q' ()>
# array(1.15139259)
